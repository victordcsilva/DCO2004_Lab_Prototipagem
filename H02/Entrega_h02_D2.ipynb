% %% [markdown]
% # Entrega h02 - D2

% %% [markdown]
% ## vtSom = [vtSom; vtSom]

% %%
close all;clc;clear all;                                          % Limpa variáveis e fecha todos os gráficos
soundFile = ['/home/victor/DCO2004_LabPSC/MATERIAL/HD_02_MATLAB/sound_01.wav'];             % Especifica do local e nome do arquivo de áudio
[vtSom, dFa] = audioread(soundFile);                              % Abre arquivo de áudio de um arquivo
% vtSom: amplitude das amostras de som
% dFa: frequência de amostrasgem do som (amostragem no tempo)
vtSom = [vtSom; vtSom];
dta = 1/dFa;                                                      % Tempo entre amostras
dTFinal = (length(vtSom)-1)*dta;                                  % Tempo da última amostra do sinal de áudio
vtTSom = 0:dta:dTFinal;                                           % Eixo temporal do arquivo de áudio
plot(vtTSom,vtSom);                                               % Plota gráfico do áudio
set(gcf,'color',[1 1 1]);                                         % Configura área da figura
set(gca,'FontWeight','bold','FontSize',12);                       % Configura área do gráfico
title(['Sinal de Áudio']);                                        % Configura título do gráfico
ylabel('Amplitude');                                              % Configura eixo X do gráfico
xlabel('Tempo (s)');                                              % Configura eixo Y do gráfico
p = audioplayer(vtSom, 1*dFa);                                    % Reproduzir arquivo de áudio
play(p);

% %% [markdown]
% Os audios são tocados e plotados em tempo diferentes.

% %% [markdown]
% ##  vtSom = [vtSom vtSom]

% %%
close all;clc;clear all;                                          % Limpa variáveis e fecha todos os gráficos
soundFile = ['/home/victor/DCO2004_LabPSC/MATERIAL/HD_02_MATLAB/sound_01.wav'];             % Especifica do local e nome do arquivo de áudio
[vtSom, dFa] = audioread(soundFile);                              % Abre arquivo de áudio de um arquivo
% vtSom: amplitude das amostras de som
% dFa: frequência de amostrasgem do som (amostragem no tempo)
vtSom = [vtSom vtSom];
dta = 1/dFa;                                                      % Tempo entre amostras
dTFinal = (length(vtSom)-1)*dta;                                  % Tempo da última amostra do sinal de áudio
vtTSom = 0:dta:dTFinal;                                           % Eixo temporal do arquivo de áudio
plot(vtTSom,vtSom);                                               % Plota gráfico do áudio
set(gcf,'color',[1 1 1]);                                         % Configura área da figura
set(gca,'FontWeight','bold','FontSize',12);                       % Configura área do gráfico
title(['Sinal de Áudio']);                                        % Configura título do gráfico
ylabel('Amplitude');                                              % Configura eixo X do gráfico
xlabel('Tempo (s)');                                              % Configura eixo Y do gráfico
p = audioplayer(vtSom, 1*dFa);                                    % Reproduzir arquivo de áudio
play(p);

% %% [markdown]
% Os dois sinais são tocados e plotados simultaneamente, mas não causa efeito diferente de quando é só um audio tocado, só é notado o plot diferente devido a mudança da cor do plot.

% %% [markdown]
% ## vtSom = [vtSom flip(vtSom)]

% %%
close all;clc;clear all;                                          % Limpa variáveis e fecha todos os gráficos
soundFile = ['/home/victor/DCO2004_LabPSC/MATERIAL/HD_02_MATLAB/sound_01.wav'];             % Especifica do local e nome do arquivo de áudio
[vtSom, dFa] = audioread(soundFile);                              % Abre arquivo de áudio de um arquivo
% vtSom: amplitude das amostras de som
% dFa: frequência de amostrasgem do som (amostragem no tempo)
vtSom = [vtSom flip(vtSom)];
dta = 1/dFa;                                                      % Tempo entre amostras
dTFinal = (length(vtSom)-1)*dta;                                  % Tempo da última amostra do sinal de áudio
vtTSom = 0:dta:dTFinal;                                           % Eixo temporal do arquivo de áudio
plot(vtTSom,vtSom);                                               % Plota gráfico do áudio
set(gcf,'color',[1 1 1]);                                         % Configura área da figura
set(gca,'FontWeight','bold','FontSize',12);                       % Configura área do gráfico
title(['Sinal de Áudio']);                                        % Configura título do gráfico
ylabel('Amplitude');                                              % Configura eixo X do gráfico
xlabel('Tempo (s)');                                              % Configura eixo Y do gráfico
p = audioplayer(vtSom, 1*dFa);                                    % Reproduzir arquivo de áudio
play(p);

% %% [markdown]
% Os dois sinais de audio são reproduzidos e plotados, sendo que o sengundo é invertido, ou seja, ele começa com baixo valores até a maior amplitude. Isso causa um efeito bacana ao se escutar com fone de ouvido, o som começa no fone da esquerda, vai baixando o volume e chega no fone da direita, e vai aumentando de volume, até finalizar.
